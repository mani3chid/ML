# %% [markdown]
# <a href="https://colab.research.google.com/github/mani3chid/ML/blob/main/Ensemble_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Ensemble Prediction and Decision Tree Model Evaluation

# %% [markdown]
# 1. Load and Preprocess Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer

file_path = "/content/drive/MyDrive/ML/wdbc.data"

# Format: ID, Diagnosis(M=malignant, B=benign), 30 features
columns = ["ID", "Diagnosis"] + [f"feature_{i}" for i in range(1, 31)]
df = pd.read_csv(file_path, header=None, names=columns)

# Drop ID (not useful for prediction)
df = df.drop("ID", axis=1)

# Encode target labels (M=1 malignant, B=0 benign)
label_encoder = LabelEncoder()
df["Diagnosis"] = label_encoder.fit_transform(df["Diagnosis"])

# Separate features & target
X = df.drop("Diagnosis", axis=1)
y = df["Diagnosis"]

# Handle missing values
imputer = SimpleImputer(strategy="mean")
X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("✅ Dataset loaded and preprocessed successfully!")
print("Shape of X:", X.shape)
print("Class distribution:\n", y.value_counts())
# Out:
# Mounted at /content/drive
# ✅ Dataset loaded and preprocessed successfully!
# Shape of X: (569, 30)
# Class distribution:
#  Diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %% [markdown]
# 2. EDA (Class Balance & Feature Correlation)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Class balance
sns.countplot(x=y)
plt.title("Class Balance (0 = Malignant, 1 = Benign)")
plt.show()

# Feature correlation heatmap
plt.figure(figsize=(10,8))
sns.heatmap(pd.DataFrame(X_scaled, columns=X.columns).corr(), cmap="coolwarm", cbar=False)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# 3. Split Dataset (Train, Validation, Test)

# %%
X_train_valid, X_test, y_train_valid, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_valid, y_train_valid, test_size=0.25, random_state=42, stratify=y_train_valid)
# 60% train, 20% validation, 20% test

# %% [markdown]
# 4. Train Models

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier, StackingClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

models = {
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Stacking": StackingClassifier(
        estimators=[
            ("svm", SVC(probability=True, random_state=42)),
            ("nb", GaussianNB()),
            ("dt", DecisionTreeClassifier(random_state=42))
        ],
        final_estimator=LogisticRegression()
    )
}

# %% [markdown]
#  5. Hyperparameter Tuning with GridSearchCV
#  6. 5-Fold Cross-Validation

# %%
param_grids = {
    "Decision Tree": {
        "criterion": ["gini", "entropy"],
        "max_depth": [3, 5, 10, None],
        "min_samples_split": [2, 5, 10],
        "min_samples_leaf": [1, 2, 4]
    },
    "AdaBoost": {
        "n_estimators": [50, 100, 200],
        "learning_rate": [0.01, 0.1, 1.0]
    },
    "Gradient Boosting": {
        "n_estimators": [100, 200],
        "learning_rate": [0.05, 0.1],
        "max_depth": [3, 5],
        "subsample": [0.8, 1.0]
    },
    "XGBoost": {
        "n_estimators": [100, 200],
        "learning_rate": [0.05, 0.1],
        "max_depth": [3, 5],
        "gamma": [0, 0.1],
        "subsample": [0.8, 1.0],
        "colsample_bytree": [0.8, 1.0]
    },
    "Random Forest": {
        "n_estimators": [100, 200],
        "max_depth": [None, 5, 10],
        "criterion": ["gini", "entropy"],
        "max_features": ["sqrt", "log2"],
        "min_samples_split": [2, 5]
    },
    "Stacking": {
        "final_estimator": [LogisticRegression(), RandomForestClassifier(n_estimators=100)]
    }
}

best_models = {}
for name, model in models.items():
    print(f"\n🔍 Tuning {name}...")
    grid = GridSearchCV(model, param_grids[name], cv=5, scoring="accuracy", n_jobs=-1)
    grid.fit(X_valid, y_valid)
    best_models[name] = grid.best_estimator_
    print(f"Best Params: {grid.best_params_}")
# Out:
# 🔍 Tuning Decision Tree...
# Best Params: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}
#
# 🔍 Tuning AdaBoost...
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#
# 🔍 Tuning Gradient Boosting...
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
#
# 🔍 Tuning XGBoost...
# Best Params: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'subsample': 1.0}
#
# 🔍 Tuning Random Forest...
# Best Params: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}
#
# 🔍 Tuning Stacking...
# Best Params: {'final_estimator': RandomForestClassifier()}

# %% [markdown]
# 7. ROC Curves & Metrics on Test Data

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, classification_report, roc_curve, auc

plt.figure(figsize=(8,6))
for name, model in best_models.items():
    model.fit(X_train_valid, y_train_valid)
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:,1]

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc_score = roc_auc_score(y_test, y_proba)

    print(f"\n{name} | Accuracy: {acc:.4f}, F1: {f1:.4f}, AUC: {auc_score:.4f}")
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))

    fpr, tpr, _ = roc_curve(y_test, y_proba)
    plt.plot(fpr, tpr, label=f"{name} (AUC={auc_score:.2f})")

plt.plot([0,1],[0,1],"k--")
plt.title("ROC Curves")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
# Out:
# Decision Tree | Accuracy: 0.9035, F1: 0.8571, AUC: 0.8750
# Confusion Matrix:
#  [[70  2]
#  [ 9 33]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93        72
#            1       0.94      0.79      0.86        42
#
#     accuracy                           0.90       114
#    macro avg       0.91      0.88      0.89       114
# weighted avg       0.91      0.90      0.90       114
#
#
# AdaBoost | Accuracy: 0.9737, F1: 0.9630, AUC: 0.9871
# Confusion Matrix:
#  [[72  0]
#  [ 3 39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        72
#            1       1.00      0.93      0.96        42
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.96      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
#
# Gradient Boosting | Accuracy: 0.9649, F1: 0.9500, AUC: 0.9970
# Confusion Matrix:
#  [[72  0]
#  [ 4 38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        72
#            1       1.00      0.90      0.95        42
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.95      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
#
# XGBoost | Accuracy: 0.9737, F1: 0.9630, AUC: 0.9954
# Confusion Matrix:
#  [[72  0]
#  [ 3 39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        72
#            1       1.00      0.93      0.96        42
#
#     accuracy                           0.97       114
#    macro avg       0.98      0.96      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
#
# Random Forest | Accuracy: 0.9649, F1: 0.9500, AUC: 0.9942
# Confusion Matrix:
#  [[72  0]
#  [ 4 38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        72
#            1       1.00      0.90      0.95        42
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.95      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
#
# Stacking | Accuracy: 0.9737, F1: 0.9639, AUC: 0.9944
# Confusion Matrix:
#  [[71  1]
#  [ 2 40]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        72
#            1       0.98      0.95      0.96        42
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
for name, model in best_models.items():
    print("Confusion Matrix of ",{name},":\n", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix of  {'Decision Tree'} :
#  [[71  1]
#  [ 2 40]]
# Confusion Matrix of  {'AdaBoost'} :
#  [[71  1]
#  [ 2 40]]
# Confusion Matrix of  {'Gradient Boosting'} :
#  [[71  1]
#  [ 2 40]]
# Confusion Matrix of  {'XGBoost'} :
#  [[71  1]
#  [ 2 40]]
# Confusion Matrix of  {'Random Forest'} :
#  [[71  1]
#  [ 2 40]]
# Confusion Matrix of  {'Stacking'} :
#  [[71  1]
#  [ 2 40]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(2, 3, figsize=(15,10))

for ax, (name, model) in zip(axes.flatten(), best_models.items()):
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=ax, cbar=False)
    ax.set_title(name)
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")

plt.tight_layout()
plt.savefig("confusion_matrix.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- Random Forest Feature Importance ---
rf_model = best_models["Random Forest"]

rf_importances = rf_model.feature_importances_
rf_indices = np.argsort(rf_importances)[::-1]

plt.figure(figsize=(10,6))
sns.barplot(x=rf_importances[rf_indices][:15], y=X.columns[rf_indices][:15], palette="viridis")
plt.title("Top 15 Feature Importances - Random Forest")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.savefig("feature_importance_rf.png")
plt.show()

# --- XGBoost Feature Importance ---
xgb_model = best_models["XGBoost"]

xgb_importances = xgb_model.feature_importances_
xgb_indices = np.argsort(xgb_importances)[::-1]

plt.figure(figsize=(10,6))
sns.barplot(x=xgb_importances[xgb_indices][:15], y=X.columns[xgb_indices][:15], palette="magma")
plt.title("Top 15 Feature Importances - XGBoost")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.savefig("feature_importance_xgb.png")
plt.show()
# Out:
# /tmp/ipython-input-256981489.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rf_importances[rf_indices][:15], y=X.columns[rf_indices][:15], palette="viridis")
# /tmp/ipython-input-256981489.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=xgb_importances[xgb_indices][:15], y=X.columns[xgb_indices][:15], palette="magma")

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
import numpy as np

# Define 5-fold CV (on training set only)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

results = {}

for name, model in best_models.items():
    acc_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring="accuracy")
    f1_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring="f1")
    auc_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring="roc_auc")

    results[name] = {
        "Accuracy": acc_scores,
        "F1": f1_scores,
        "AUC": auc_scores
    }

# Print results
for name, metrics in results.items():
    print(f"\n{name}")
    print(f"  Accuracy folds: {metrics['Accuracy']} | Avg = {metrics['Accuracy'].mean():.4f}")
    print(f"  F1 folds:       {metrics['F1']} | Avg = {metrics['F1'].mean():.4f}")
    print(f"  AUC folds:      {metrics['AUC']} | Avg = {metrics['AUC'].mean():.4f}")
# Out:
# Decision Tree
#   Accuracy folds: [0.92753623 0.97058824 0.97058824 0.94117647 0.95588235] | Avg = 0.9532
#   F1 folds:       [0.90196078 0.96296296 0.96       0.92307692 0.94117647] | Avg = 0.9378
#   AUC folds:      [0.88774597 0.97619048 0.96930233 0.95348837 0.97348837] | Avg = 0.9520
#
# AdaBoost
#   Accuracy folds: [0.92753623 0.98529412 1.         0.98529412 1.        ] | Avg = 0.9796
#   F1 folds:       [0.89795918 0.98113208 1.         0.97959184 1.        ] | Avg = 0.9717
#   AUC folds:      [0.98300537 1.         1.         0.97860465 1.        ] | Avg = 0.9923
#
# Gradient Boosting
#   Accuracy folds: [0.94202899 0.95588235 0.98529412 0.98529412 0.95588235] | Avg = 0.9649
#   F1 folds:       [0.91666667 0.94339623 0.97959184 0.97959184 0.94117647] | Avg = 0.9521
#   AUC folds:      [0.96243292 0.99450549 1.         0.99023256 0.9972093 ] | Avg = 0.9889
#
# XGBoost
#   Accuracy folds: [0.94202899 0.98529412 0.98529412 0.98529412 0.98529412] | Avg = 0.9766
#   F1 folds:       [0.91666667 0.98113208 0.97959184 0.97959184 0.98039216] | Avg = 0.9675
#   AUC folds:      [0.97853309 1.         1.         0.97488372 0.99906977] | Avg = 0.9905
#
# Random Forest
#   Accuracy folds: [0.92753623 0.92647059 0.97058824 0.95588235 0.97058824] | Avg = 0.9502
#   F1 folds:       [0.89361702 0.90909091 0.95833333 0.93877551 0.96153846] | Avg = 0.9323
#   AUC folds:      [0.96019678 0.98626374 1.         0.98837209 0.99813953] | Avg = 0.9866
#
# Stacking
#   Accuracy folds: [0.92753623 0.97058824 0.95588235 0.97058824 1.        ] | Avg = 0.9649
#   F1 folds:       [0.89795918 0.96296296 0.92       0.97959184 1.        ] | Avg = 0.9521
#   AUC folds:      [0.9588551  0.996337   0.99348837 0.97534884 1.        ] | Avg = 0.9848

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV

# This loop will run the tuning and store the results
all_results = {}

for name, model in models.items():
    print(f"--- Tuning {name} ---")

    # 1. Define GridSearchCV to calculate both 'accuracy' and 'f1' in one go
    # refit='accuracy' tells it to pick the best model based on the accuracy score
    grid = GridSearchCV(
        estimator=model,
        param_grid=param_grids[name],
        scoring={'accuracy': 'accuracy', 'f1': 'f1'},
        refit='accuracy',
        cv=5,
        n_jobs=-1  # Uses all available CPU cores to speed up
    )

    # 2. Run the grid search
    grid.fit(X_train, y_train)

    # 3. Save the results
    all_results[name] = pd.DataFrame(grid.cv_results_)

# --- Display the Results ---
# Now, print the tables using the saved results

print("\n\n--- Hyperparameter Tuning Results ---")

for name, results_df in all_results.items():
    print(f"\n📊 Table: {name}")

    # Select only the columns you need for the report
    columns_to_show = ['params', 'mean_test_accuracy', 'mean_test_f1']

    # Rename columns for clarity
    display_df = results_df[columns_to_show].rename(columns={
        'mean_test_accuracy': 'Accuracy',
        'mean_test_f1': 'F1 Score'
    })

    display(display_df.sort_values(by='Accuracy', ascending=False))
# Out:
# --- Tuning Decision Tree ---
# --- Tuning AdaBoost ---
# --- Tuning Gradient Boosting ---
# --- Tuning XGBoost ---
# --- Tuning Random Forest ---
# --- Tuning Stacking ---
#
#
# --- Hyperparameter Tuning Results ---
#
# 📊 Table: Decision Tree
#                                                params  Accuracy  F1 Score
# 36  {'criterion': 'entropy', 'max_depth': 3, 'min_...  0.947187  0.927827
# 37  {'criterion': 'entropy', 'max_depth': 3, 'min_...  0.947187  0.927827
# 0   {'criterion': 'gini', 'max_depth': 3, 'min_sam...  0.938406  0.914707
# 1   {'criterion': 'gini', 'max_depth': 3, 'min_sam...  0.938406  0.914707
# 40  {'criterion': 'entropy', 'max_depth': 3, 'min_...  0.935592  0.909805
# ..                                                ...       ...       ...
# 22  {'criterion': 'gini', 'max_depth': 10, 'min_sa...  0.903325  0.865977
# 30  {'criterion': 'gini', 'max_depth': None, 'min_...  0.903325  0.867679
# 31  {'criterion': 'gini', 'max_depth': None, 'min_...  0.903325  0.865977
# 13  {'criterion': 'gini', 'max_depth': 5, 'min_sam...  0.900426  0.862499
# 12  {'criterion': 'gini', 'max_depth': 5, 'min_sam...  0.897528  0.859169
#
# [72 rows x 3 columns]
# 📊 Table: AdaBoost
#                                          params  Accuracy  F1 Score
# 7   {'learning_rate': 1.0, 'n_estimators': 100}  0.973572  0.963752
# 8   {'learning_rate': 1.0, 'n_estimators': 200}  0.967732  0.955585
# 6    {'learning_rate': 1.0, 'n_estimators': 50}  0.964791  0.951673
# 5   {'learning_rate': 0.1, 'n_estimators': 200}  0.961807  0.947058
# 4   {'learning_rate': 0.1, 'n_estimators': 100}  0.958866  0.942823
# 3    {'learning_rate': 0.1, 'n_estimators': 50}  0.950085  0.931729
# 2  {'learning_rate': 0.01, 'n_estimators': 200}  0.926684  0.898725
# 0   {'learning_rate': 0.01, 'n_estimators': 50}  0.903197  0.860472
# 1  {'learning_rate': 0.01, 'n_estimators': 100}  0.903197  0.861559
# 📊 Table: Gradient Boosting
#                                                params  Accuracy  F1 Score
# 10  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...  0.961765  0.947360
# 12  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.958951  0.943184
# 6   {'learning_rate': 0.05, 'max_depth': 5, 'n_est...  0.958866  0.944128
# 14  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.958866  0.943303
# 4   {'learning_rate': 0.05, 'max_depth': 5, 'n_est...  0.953026  0.936451
# 2   {'learning_rate': 0.05, 'max_depth': 3, 'n_est...  0.952941  0.936857
# 1   {'learning_rate': 0.05, 'max_depth': 3, 'n_est...  0.950085  0.932674
# 11  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...  0.947229  0.927469
# 9   {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...  0.947187  0.928097
# 3   {'learning_rate': 0.05, 'max_depth': 3, 'n_est...  0.947144  0.928242
# 8   {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...  0.947101  0.927940
# 0   {'learning_rate': 0.05, 'max_depth': 3, 'n_est...  0.944203  0.925583
# 15  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.914962  0.887330
# 13  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  0.914919  0.887330
# 7   {'learning_rate': 0.05, 'max_depth': 5, 'n_est...  0.914876  0.887469
# 5   {'learning_rate': 0.05, 'max_depth': 5, 'n_est...  0.909079  0.879469
# 📊 Table: XGBoost
#                                                params  Accuracy  F1 Score
# 14  {'colsample_bytree': 0.8, 'gamma': 0, 'learnin...  0.973572  0.963752
# 11  {'colsample_bytree': 0.8, 'gamma': 0, 'learnin...  0.970631  0.959663
# 26  {'colsample_bytree': 0.8, 'gamma': 0.1, 'learn...  0.970631  0.959647
# 46  {'colsample_bytree': 1.0, 'gamma': 0, 'learnin...  0.970631  0.959507
# 42  {'colsample_bytree': 1.0, 'gamma': 0, 'learnin...  0.967732  0.955429
# ..                                                ...       ...       ...
# 25  {'colsample_bytree': 0.8, 'gamma': 0.1, 'learn...  0.956010  0.939909
# 53  {'colsample_bytree': 1.0, 'gamma': 0.1, 'learn...  0.956010  0.940069
# 61  {'colsample_bytree': 1.0, 'gamma': 0.1, 'learn...  0.956010  0.939909
# 3   {'colsample_bytree': 0.8, 'gamma': 0, 'learnin...  0.955968  0.940534
# 23  {'colsample_bytree': 0.8, 'gamma': 0.1, 'learn...  0.953026  0.937050
#
# [64 rows x 3 columns]
# 📊 Table: Random Forest
#                                                params  Accuracy  F1 Score
# 36  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.964749  0.951648
# 44  {'criterion': 'entropy', 'max_depth': 10, 'max...  0.958909  0.944122
# 28  {'criterion': 'entropy', 'max_depth': None, 'm...  0.958909  0.944122
# 38  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.958909  0.943965
# 37  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.958866  0.944285
# 6   {'criterion': 'gini', 'max_depth': None, 'max_...  0.955968  0.940210
# 22  {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.955968  0.940210
# 12  {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.955968  0.939877
# 45  {'criterion': 'entropy', 'max_depth': 10, 'max...  0.955968  0.940357
# 29  {'criterion': 'entropy', 'max_depth': None, 'm...  0.955968  0.940357
# 32  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.955925  0.939240
# 40  {'criterion': 'entropy', 'max_depth': 10, 'max...  0.955925  0.939240
# 24  {'criterion': 'entropy', 'max_depth': None, 'm...  0.955925  0.939240
# 20  {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.953026  0.936122
# 14  {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.953026  0.935974
# 4   {'criterion': 'gini', 'max_depth': None, 'max_...  0.953026  0.936122
# 34  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.952984  0.934832
# 26  {'criterion': 'entropy', 'max_depth': None, 'm...  0.952984  0.934832
# 42  {'criterion': 'entropy', 'max_depth': 10, 'max...  0.952984  0.934832
# 0   {'criterion': 'gini', 'max_depth': None, 'max_...  0.952984  0.935500
# 13  {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.952984  0.935980
# 16  {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.952984  0.935500
# 8   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.952941  0.935667
# 27  {'criterion': 'entropy', 'max_depth': None, 'm...  0.950128  0.931224
# 43  {'criterion': 'entropy', 'max_depth': 10, 'max...  0.950128  0.931224
# 1   {'criterion': 'gini', 'max_depth': None, 'max_...  0.950085  0.931729
# 46  {'criterion': 'entropy', 'max_depth': 10, 'max...  0.950085  0.931729
# 17  {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.950085  0.931729
# 30  {'criterion': 'entropy', 'max_depth': None, 'm...  0.950085  0.931729
# 21  {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.950085  0.932210
# 5   {'criterion': 'gini', 'max_depth': None, 'max_...  0.950085  0.932210
# 10  {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.950043  0.931893
# 31  {'criterion': 'entropy', 'max_depth': None, 'm...  0.950043  0.931893
# 47  {'criterion': 'entropy', 'max_depth': 10, 'max...  0.950043  0.931893
# 39  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.947144  0.927974
# 23  {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.947144  0.927974
# 15  {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.947144  0.927974
# 7   {'criterion': 'gini', 'max_depth': None, 'max_...  0.947144  0.927974
# 2   {'criterion': 'gini', 'max_depth': None, 'max_...  0.947101  0.928285
# 9   {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.947101  0.927834
# 18  {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.947101  0.928285
# 35  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.944246  0.923224
# 33  {'criterion': 'entropy', 'max_depth': 5, 'max_...  0.944246  0.923224
# 3   {'criterion': 'gini', 'max_depth': None, 'max_...  0.944203  0.924063
# 11  {'criterion': 'gini', 'max_depth': 5, 'max_fea...  0.944203  0.923755
# 19  {'criterion': 'gini', 'max_depth': 10, 'max_fe...  0.944203  0.924063
# 25  {'criterion': 'entropy', 'max_depth': None, 'm...  0.941304  0.919469
# 41  {'criterion': 'entropy', 'max_depth': 10, 'max...  0.941304  0.919469
# 📊 Table: Stacking
#                                           params  Accuracy  F1 Score
# 0      {'final_estimator': LogisticRegression()}   0.96769  0.956514
# 1  {'final_estimator': RandomForestClassifier()}   0.96185  0.947890
